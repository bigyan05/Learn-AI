# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# 2025-07-03 11:17:25.766927: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-03 11:17:26.297484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751541446.469389    2112 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751541446.512326    2112 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-03 11:17:27.100348: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# cache_dir indicates where to download data.  "." means current directory
# untar true will unzip it

# %%
data_dir
# Out:
# './datasets/flower_photos'

# %%
import pathlib  

data_dir = pathlib.Path(data_dir)  # Convert 'data_dir' to a Path object for easier path handling
data_dir
# Out:
# PosixPath('datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('datasets/flower_photos/sunflowers/2588453601_66f2a03cca_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/5970869550_d7d9fabebd_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/3894586562_5dbbdc4354_n.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/6125761554_4e72819ce4_m.jpg'),
#  PosixPath('datasets/flower_photos/sunflowers/20972862281_5367f4af88.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [PosixPath('datasets/flower_photos/roses/4609168052_3d4e1d3804_n.jpg'),
#  PosixPath('datasets/flower_photos/roses/16643944275_3cd4cd966c.jpg'),
#  PosixPath('datasets/flower_photos/roses/5736328472_8f25e6f6e7.jpg'),
#  PosixPath('datasets/flower_photos/roses/7285188160_49d84b95a3_m.jpg'),
#  PosixPath('datasets/flower_photos/roses/3661675690_ed2d05fa5f_n.jpg')]

# %%
PIL.Image.open(str(roses[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x257>

# %%
tulips = list(data_dir.glob('tulips/*'))
PIL.Image.open(str(tulips[4]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x212>

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %% [markdown]
# ### Using opencv to read image

# %%
X, y = [], []  # Initialize empty lists for images (X) and their labels (y)

# Loop through each flower category and its image paths
for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))  # Read the image using OpenCV
        resized_img = cv2.resize(img, (180, 180))  # Resize image to 180x180 pixels
        X.append(resized_img)  # Add the processed image to the list
        y.append(flowers_labels_dict[flower_name])  # Add the corresponding label

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ### Scaling Images

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# ## CNN

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train, y_train, epochs=30)
# Out:
# 2025-07-03 11:17:41.725401: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1751541461.726317    2112 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3539 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751541475.235948    2214 service.cc:148] XLA service 0x7b840c014dc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751541475.237598    2214 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2025-07-03 11:17:55.416287: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1751541492.743169    2214 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  4/86 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.2070 - loss: 1.9724
# I0000 00:00:1751541499.058771    2214 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.3542 - loss: 1.4922
# Epoch 2/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6150 - loss: 0.9873
# Epoch 3/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6957 - loss: 0.7869
# Epoch 4/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ -14s -168372us/step - accuracy: 0.8126 - loss: 0.5508
# Epoch 5/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 19s 226ms/step - accuracy: 0.8823 - loss: 0.3527
# Epoch 6/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ -14s -168619us/step - accuracy: 0.9476 - loss: 0.1941
# Epoch 7/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 19s 228ms/step - accuracy: 0.9731 - loss: 0.1079
# Epoch 8/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ -14s -168782us/step - accuracy: 0.9778 - loss: 0.0805
# Epoch 9/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9904 - loss: 0.0359
# Epoch 10/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9994 - loss: 0.0212
# Epoch 11/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9973 - loss: 0.0192
# Epoch 12/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9996 - loss: 0.0078
# Epoch 13/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9995 - loss: 0.0076
# Epoch 14/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9999 - loss: 0.0026
# Epoch 15/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9999 - loss: 0.0022
# Epoch 16/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9993 - loss: 0.0036
# Epoch 17/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9995 - loss: 0.0046
# Epoch 18/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 19s 221ms/step - accuracy: 0.9997 - loss: 0.0034
# Epoch 19/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9998 - loss: 0.0018
# Epoch 20/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9989 - loss: 0.0079
# Epoch 21/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9989 - loss: 0.0064
# Epoch 22/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9997 - loss: 0.0020
# Epoch 23/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9989 - loss: 0.0053
# Epoch 24/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9999 - loss: 7.6236e-04
# Epoch 25/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ -15s -173125us/step - accuracy: 0.9997 - loss: 0.0028
# Epoch 26/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9994 - loss: 0.0032
# Epoch 27/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 1.0000 - loss: 8.7438e-04
# Epoch 28/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9979 - loss: 0.0067
# Epoch 29/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9998 - loss: 0.0022
# Epoch 30/30
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9995 - loss: 0.0027

# %%
model.evaluate(X_test,y_test)
# Out:
# 25/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6769 - loss: 2.0988
# 2025-07-03 11:19:32.410440: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng24{k2=0,k13=2,k14=3,k18=0,k23=0} for conv (f32[22,16,180,180]{3,2,1,0}, u8[0]{0}) custom-call(f32[22,3,180,180]{3,2,1,0}, f32[16,3,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-07-03 11:19:32.417763: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 16.732860828s
# Trying algorithm eng24{k2=0,k13=2,k14=3,k18=0,k23=0} for conv (f32[22,16,180,180]{3,2,1,0}, u8[0]{0}) custom-call(f32[22,3,180,180]{3,2,1,0}, f32[16,3,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.6751 - loss: 2.1076
# [2.162590980529785, 0.6623093485832214]

# %% [markdown]
# Training accuracy is .99 and testing is .63 so, clearly is an overfit

# %% [markdown]
# ### Trying to check prediction

# %%
predictions = model.predict(X_test)
predictions
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# array([[  3.377081  ,   2.741018  ,  -3.3343587 , -22.164726  ,
#           1.6379842 ],
#        [  6.0556    ,  -6.976388  , -19.33376   , -11.64354   ,
#          11.226506  ],
#        [ -5.6682386 ,  -7.561666  ,   6.105506  ,  -3.2475655 ,
#          -1.0695581 ],
#        ...,
#        [ -6.927577  ,   0.69887793,  -0.8020649 ,  11.68654   ,
#           2.1872048 ],
#        [ -1.3689559 ,   2.1028817 , -13.179885  ,  -2.5760465 ,
#           7.508116  ],
#        [ -0.11618944,  -6.070709  ,  -4.6331806 ,   7.0247307 ,
#           4.6862264 ]], dtype=float32)

# %%
score = tf.nn.softmax(predictions[0])
print(np.argmax(score))
# Out:
# 0

# %%
print(y_test[0])
# Out:
# 1

# %% [markdown]
# Seems like it did predicted correctly

# %% [markdown]
# ## Performing Data Augmentation now

# %%
da = keras.Sequential([layers.RandomZoom(0.9)])

# %%
plt.imshow(X_train[23])

# %%
data_augmentation = keras.Sequential([
    # Randomly flip images horizontally during training
    layers.RandomFlip(mode="horizontal", seed=None, input_shape=(180, 180, 3)),

    # Randomly rotate images by up to 10%
    layers.RandomRotation(0.1),

    # Randomly zoom in on images by up to 10%
    layers.RandomZoom(0.1),
])
